# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Load merged dataset
df = pd.read_csv(r"C:\Users\Radhika\OneDrive\Desktop\Radhika_klypto\data\nifty merged 5min.csv")
print(df.head())
# Out:
#   Index Name        Date  Open_spot  High_spot  Low_spot  Close_spot Symbol  \
# 0   NIFTY 50  2025-01-14   23165.90   23264.95  23134.15    23176.05    NaN
# 1   NIFTY 50  2025-01-15   23250.45   23293.65  23146.45    23213.20    NaN
# 2   NIFTY 50  2025-01-16   23377.25   23391.65  23272.05    23311.80    NaN
# 3   NIFTY 50  2025-01-17   23277.10   23292.10  23100.35    23203.20    NaN
# 4   NIFTY 50  2025-01-20   23290.40   23391.10  23170.65    23344.75    NaN
#
#   Expiry  Open_fut  High_fut  ...  DaysToExpiry   TradeDate  STRIKE  LTP_y  \
# 0    NaN       NaN       NaN  ...           NaN  2025-01-14     NaN    NaN
# 1    NaN       NaN       NaN  ...           NaN  2025-01-15     NaN    NaN
# 2    NaN       NaN       NaN  ...           NaN  2025-01-16     NaN    NaN
# 3    NaN       NaN       NaN  ...           NaN  2025-01-17     NaN    NaN
# 4    NaN       NaN       NaN  ...           NaN  2025-01-20     NaN    NaN
#
#    IV  VOLUME  OI  CHNG IN OI  OptionType  ATM
# 0 NaN     NaN NaN         NaN         NaN  NaN
# 1 NaN     NaN NaN         NaN         NaN  NaN
# 2 NaN     NaN NaN         NaN         NaN  NaN
# 3 NaN     NaN NaN         NaN         NaN  NaN
# 4 NaN     NaN NaN         NaN         NaN  NaN
#
# [5 rows x 29 columns]

# %%
# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Sort data properly
df = df.sort_values('Date').reset_index(drop=True)

# %% [markdown]
# # EMA INDICATORS

# %%
# Fast EMA
df['EMA_5'] = df['Close_spot'].ewm(span=5, adjust=False).mean()

# Slow EMA
df['EMA_15'] = df['Close_spot'].ewm(span=15, adjust=False).mean()

# %% [markdown]
# # RETURNS

# %%
# Spot returns
df['Spot_Return'] = np.log(df['Close_spot'] / df['Close_spot'].shift(1))

# Futures returns (will be NaN until futures data exists)
df['Futures_Return'] = np.log(df['Close_fut'] / df['Close_fut'].shift(1))

# %% [markdown]
# # FUTURES BASIS

# %%
df['Futures_Basis'] = (df['Close_fut'] - df['Close_spot']) / df['Close_spot']

# %% [markdown]
# # Task 2.1

# %% [markdown]
# What we need:
#
# Spot price
#
# Strike
#
# Time to expiry (in years)
#
# IV
#
# Risk-free rate = 6.5%

# %%
pip install pandas numpy py_vollib
# Out:
# Requirement already satisfied: pandas in c:\users\radhika\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\radhika\anaconda3\lib\site-packages (1.26.3)
# Requirement already satisfied: py_vollib in c:\users\radhika\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\radhika\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\radhika\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\radhika\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: py-lets-be-rational in c:\users\radhika\anaconda3\lib\site-packages (from py_vollib) (1.0.1)
# Requirement already satisfied: simplejson in c:\users\radhika\anaconda3\lib\site-packages (from py_vollib) (3.20.2)
# Requirement already satisfied: scipy in c:\users\radhika\anaconda3\lib\site-packages (from py_vollib) (1.11.4)
# Requirement already satisfied: six>=1.5 in c:\users\radhika\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from py_vollib.black_scholes.greeks.analytical import delta, gamma, theta, vega, rho

RISK_FREE_RATE = 0.065

# %% [markdown]
# ## Delta

# %%
df['Delta'] = df.apply(
    lambda x: delta(
        'c' if x['OptionType'] == 'CE' else 'p',
        x['Close_spot'],
        x['STRIKE'],
        x['Time_to_Expiry'],
        RISK_FREE_RATE,
        x['IV'])
    if pd.notna(x['IV']) else np.nan, axis=1)

# %% [markdown]
# # Gamma

# %%
df['Gamma'] = df.apply(
    lambda x: gamma(
        'c' if x['OptionType'] == 'CE' else 'p',
        x['Close_spot'],
        x['STRIKE'],
        x['Time_to_Expiry'],
        RISK_FREE_RATE,
        x['IV'])
    if pd.notna(x['IV']) else np.nan,axis=1)

# %% [markdown]
# ## Theta

# %%
df['Theta'] = df.apply(
    lambda x: theta(
        'c' if x['OptionType'] == 'CE' else 'p',
        x['Close_spot'],
        x['STRIKE'],
        x['Time_to_Expiry'],
        RISK_FREE_RATE,
        x['IV']) 
    if pd.notna(x['IV']) else np.nan,axis=1)

# %% [markdown]
# ## Vega

# %%
df['Vega'] = df.apply(
    lambda x: vega(
        'c' if x['OptionType'] == 'CE' else 'p',
        x['Close_spot'],
        x['STRIKE'],
        x['Time_to_Expiry'],
        RISK_FREE_RATE,
        x['IV']) 
    if pd.notna(x['IV']) else np.nan,axis=1)

# %% [markdown]
# ## Rho

# %%
df['Rho'] = df.apply(
    lambda x: rho(
        'c' if x['OptionType'] == 'CE' else 'p',
        x['Close_spot'],
        x['STRIKE'],
        x['Time_to_Expiry'],
        RISK_FREE_RATE,
        x['IV'])
    if pd.notna(x['IV']) else np.nan,axis=1)

# %% [markdown]
# ## PCR_OI & PCR_VOLUME

# %%
df['PCR_OI'] = df.groupby('Date')['OI'].transform(
    lambda x: x[df['OptionType'] == 'PE'].sum() /
              x[df['OptionType'] == 'CE'].sum())

df['PCR_VOLUME'] = df.groupby('Date')['VOLUME'].transform(
    lambda x: x[df['OptionType'] == 'PE'].sum() /
              x[df['OptionType'] == 'CE'].sum())

# %% [markdown]
# ## Gamma_Exposure

# %%
df['Gamma_Exposure'] = df['Close_spot'] * df['Gamma'] * df['OI']

# %% [markdown]
# ## Call_IV, Put_IV, Average_IV, IV_Spread

# %%
df['Call_IV'] = df['IV'].where(df['OptionType'] == 'CE')
df['Put_IV'] = df['IV'].where(df['OptionType'] == 'PE')

df['Average_IV'] = (df['Call_IV'] + df['Put_IV']) / 2

df['IV_Spread'] = df['Call_IV'] - df['Put_IV']

# %% [markdown]
# ## Futures_Basis

# %%
df['Futures_Basis'] = (df['Close_fut'] - df['Close_spot']) / df['Close_spot']

# %% [markdown]
# ## Spot_Return & Futures_Return

# %%
df['Spot_Return'] = np.log(df['Close_spot'] / df['Close_spot'].shift(1))

df['Futures_Return'] = np.log(df['Close_fut'] / df['Close_fut'].shift(1))

# %% [markdown]
# ## Call_Delta, Put_Delta, Delta_Neutral_Ratio

# %%
df['Call_Delta'] = df['Delta'].where(df['OptionType'] == 'CE')
df['Put_Delta'] = df['Delta'].where(df['OptionType'] == 'PE')

df['Delta_Neutral_Ratio'] = abs(df['Call_Delta']) / abs(df['Put_Delta'])

# %%
final_features = df.copy()

final_features.to_csv(r"C:\Users\Radhika\OneDrive\Desktop\Radhika_klypto\data\nifty_features_5min.csv", index=False)
