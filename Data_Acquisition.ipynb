# %%
# Import pandas library for data handling
import pandas as pd

# STEP 1: Load the CSV file

# Load NIFTY Spot 5-minute data
spot_df = pd.read_csv(r"C:\Users\Radhika\OneDrive\Desktop\Radhika_klypto\data\nifty_futures_5min.csv")

# Load NIFTY Futures 5-minute data
futures_df = pd.read_csv(r"C:\Users\Radhika\OneDrive\Desktop\Radhika_klypto\data\nifty_options_5min.csv")

# Load NIFTY Options data
options_df = pd.read_csv(r"C:\Users\Radhika\OneDrive\Desktop\Radhika_klypto\data\nifty_spot_5min.csv")
                         
# STEP 2: Display first 5 rows

print("NIFTY Spot Data")
print(spot_df.head())
print("\n")

print("NIFTY Futures Data")
print(futures_df.head())
print("\n")

print("NIFTY Options Data")
print(options_df.head())
print("\n")


# STEP 3: Check dataset shape
# Shape tells us: (number of rows, number of columns)

print("Dataset Shapes:")
print("Spot Data Shape     :", spot_df.shape)
print("Futures Data Shape  :", futures_df.shape)
print("Options Data Shape  :", options_df.shape)

# STEP 4: Check column names

print("\n Spot Columns:")
print(spot_df.columns)

print("\n Futures Columns:")
print(futures_df.columns)

print("\n Options Columns:")
print(options_df.columns)
# Out:
# NIFTY Spot Data
#   Symbol         Date       Expiry     Open     High      Low    Close    \
# 0    NIFTY  14-Jan-2026  27-Jan-2026  25750.1  25850.0  25670.0  25719.0
# 1    NIFTY  13-Jan-2026  27-Jan-2026  25911.0  25934.8  25661.1  25790.8
# 2    NIFTY  12-Jan-2026  27-Jan-2026  25770.0  25899.0  25573.2  25876.0
# 3    NIFTY  09-Jan-2026  27-Jan-2026  25966.0  26031.6  25725.0  25788.3
# 4    NIFTY  08-Jan-2026  27-Jan-2026  26190.0  26210.0  25965.0  25985.6
#
#      LTP    Settle Price    No. of contracts    Turnover * in   ₹ Lakhs  \
# 0  25728.0         25719.0             70661.0               1182853.41
# 1  25780.4         25790.8             87482.0               1466541.07
# 2  25880.0         25876.0            121833.0               2038827.80
# 3  25810.8         25788.3             89699.0               1507538.52
# 4  25965.0         25985.6            106366.0               1802312.30
#
#    Open Int    Change in OI    Underlying Value
# ...
